# %% [markdown]
# ### Check ImageLevel

# %%
from src.datasets import HiddenObjectsImageLevel

# %%
ds = HiddenObjectsImageLevel()

# %%
ds[0]
# Out:
# {'image': tensor([[[0.3098, 0.3098, 0.3059,  ..., 0.6118, 0.6118, 0.6118],
#           [0.3098, 0.3098, 0.3059,  ..., 0.6157, 0.6118, 0.6118],
#           [0.3098, 0.3098, 0.3098,  ..., 0.6157, 0.6157, 0.6118],
#           ...,
#           [0.6784, 0.6471, 0.6196,  ..., 0.5765, 0.5765, 0.5765],
#           [0.6784, 0.6431, 0.6118,  ..., 0.5765, 0.5765, 0.5765],
#           [0.6784, 0.6431, 0.6118,  ..., 0.5765, 0.5765, 0.5765]],
#
#          [[0.2667, 0.2667, 0.2627,  ..., 0.5922, 0.5922, 0.5922],
#           [0.2667, 0.2667, 0.2627,  ..., 0.5961, 0.5922, 0.5922],
#           [0.2667, 0.2667, 0.2667,  ..., 0.5961, 0.5961, 0.5922],
#           ...,
#           [0.6431, 0.6314, 0.6000,  ..., 0.5647, 0.5647, 0.5647],
#           [0.6431, 0.6275, 0.5922,  ..., 0.5647, 0.5647, 0.5647],
#           [0.6431, 0.6275, 0.5922,  ..., 0.5647, 0.5647, 0.5647]],
#
#          [[0.3294, 0.3294, 0.3255,  ..., 0.6078, 0.6078, 0.6078],
# ...

# %%
ds[0]['entry_ids'].unique()
# Out:
# tensor([ 1,  9, 27])

# %%
set(ds[0]['classes'])
# Out:
# {'bottle', 'fork', 'spoon'}

# %% [markdown]
# ### Check ImageClassLevel

# %%
from src.datasets import HiddenObjectsImageClassLevel

# %%
ds = HiddenObjectsImageClassLevel()

# %%
ds[0]
# Out:
# {'image': tensor([[[0.3098, 0.3098, 0.3059,  ..., 0.6118, 0.6118, 0.6118],
#           [0.3098, 0.3098, 0.3059,  ..., 0.6157, 0.6118, 0.6118],
#           [0.3098, 0.3098, 0.3098,  ..., 0.6157, 0.6157, 0.6118],
#           ...,
#           [0.6784, 0.6471, 0.6196,  ..., 0.5765, 0.5765, 0.5765],
#           [0.6784, 0.6431, 0.6118,  ..., 0.5765, 0.5765, 0.5765],
#           [0.6784, 0.6431, 0.6118,  ..., 0.5765, 0.5765, 0.5765]],
#
#          [[0.2667, 0.2667, 0.2627,  ..., 0.5922, 0.5922, 0.5922],
#           [0.2667, 0.2667, 0.2627,  ..., 0.5961, 0.5922, 0.5922],
#           [0.2667, 0.2667, 0.2667,  ..., 0.5961, 0.5961, 0.5922],
#           ...,
#           [0.6431, 0.6314, 0.6000,  ..., 0.5647, 0.5647, 0.5647],
#           [0.6431, 0.6275, 0.5922,  ..., 0.5647, 0.5647, 0.5647],
#           [0.6431, 0.6275, 0.5922,  ..., 0.5647, 0.5647, 0.5647]],
#
#          [[0.3294, 0.3294, 0.3255,  ..., 0.6078, 0.6078, 0.6078],
# ...

# %%
ds[0]['boxes'].shape
# Out:
# torch.Size([1012, 4])
